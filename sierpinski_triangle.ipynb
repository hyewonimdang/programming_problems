# %%
def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski_triangle_coordinates(depth, p1, p2, p3):
    if depth == 0:
        return [midpoint(p1, p2), midpoint(p2, p3), midpoint(p3, p1)]
    else:
        # Calculate midpoints of the sides
        mid1 = midpoint(p1, p2)
        mid2 = midpoint(p2, p3)
        mid3 = midpoint(p3, p1)

        # Recursive calls for the three sub-triangles
        coordinates = []
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, p1, mid1, mid3))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid1, p2, mid2))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid3, mid2, p3))
        return coordinates

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0, 0], [1, 0], [0.5, np.sqrt(3)/2]])

# 원하는 단계까지의 좌표 얻기
depth = 3
coordinates = sierpinski_triangle_coordinates(depth, triangle_points[0], triangle_points[1], triangle_points[2])

# 좌표 출력
for i, coord in enumerate(coordinates):
    print(f"Triangle {i + 1} midpoint coordinates: {coord}")
# Out:
# Triangle 1 midpoint coordinates: (0.0625, 0.0)
# Triangle 2 midpoint coordinates: (0.09375, 0.05412658773652741)
# Triangle 3 midpoint coordinates: (0.03125, 0.05412658773652741)
# Triangle 4 midpoint coordinates: (0.1875, 0.0)
# Triangle 5 midpoint coordinates: (0.21875, 0.05412658773652741)
# Triangle 6 midpoint coordinates: (0.15625, 0.05412658773652741)
# Triangle 7 midpoint coordinates: (0.125, 0.10825317547305482)
# Triangle 8 midpoint coordinates: (0.15625, 0.16237976320958225)
# Triangle 9 midpoint coordinates: (0.09375, 0.16237976320958225)
# Triangle 10 midpoint coordinates: (0.3125, 0.0)
# Triangle 11 midpoint coordinates: (0.34375, 0.05412658773652741)
# Triangle 12 midpoint coordinates: (0.28125, 0.05412658773652741)
# Triangle 13 midpoint coordinates: (0.4375, 0.0)
# Triangle 14 midpoint coordinates: (0.46875, 0.05412658773652741)
# Triangle 15 midpoint coordinates: (0.40625, 0.05412658773652741)
# Triangle 16 midpoint coordinates: (0.375, 0.10825317547305482)
# ...

# %%
def sierpinski_triangle_coordinates(depth, p1, p2, p3):
    if depth == 0:
        return [midpoint(p1, p2), midpoint(p2, p3), midpoint(p3, p1)]
    else:
        # Calculate midpoints of the sides
        mid1 = midpoint(p1, p2)
        mid2 = midpoint(p2, p3)
        mid3 = midpoint(p3, p1)

        # Recursive calls for the three sub-triangles
        coordinates = []
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, p1, mid1, mid3))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid1, p2, mid2))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid3, mid2, p3))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid1, mid2, mid3))  # 추가: 중점 좌표 저장
        return coordinates

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0, 0], [1, 0], [0.5, np.sqrt(3)/2]])

# 원하는 단계까지의 좌표 얻기
depth = 3
coordinates = sierpinski_triangle_coordinates(depth, triangle_points[0], triangle_points[1], triangle_points[2])

# 좌표 출력
for i, coord in enumerate(coordinates):
    print(f"Point {i + 1} coordinates: {coord}")
# Out:
# Point 1 coordinates: (0.0625, 0.0)
# Point 2 coordinates: (0.09375, 0.05412658773652741)
# Point 3 coordinates: (0.03125, 0.05412658773652741)
# Point 4 coordinates: (0.1875, 0.0)
# Point 5 coordinates: (0.21875, 0.05412658773652741)
# Point 6 coordinates: (0.15625, 0.05412658773652741)
# Point 7 coordinates: (0.125, 0.10825317547305482)
# Point 8 coordinates: (0.15625, 0.16237976320958225)
# Point 9 coordinates: (0.09375, 0.16237976320958225)
# Point 10 coordinates: (0.15625, 0.05412658773652741)
# Point 11 coordinates: (0.125, 0.10825317547305482)
# Point 12 coordinates: (0.09375, 0.05412658773652741)
# Point 13 coordinates: (0.3125, 0.0)
# Point 14 coordinates: (0.34375, 0.05412658773652741)
# Point 15 coordinates: (0.28125, 0.05412658773652741)
# Point 16 coordinates: (0.4375, 0.0)
# Point 17 coordinates: (0.46875, 0.05412658773652741)
# Point 18 coordinates: (0.40625, 0.05412658773652741)
# Point 19 coordinates: (0.375, 0.10825317547305482)
# ...

# %%
import numpy as np

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski_triangle_coordinates(depth, p1, p2, p3):
    if depth == 0:
        return [midpoint(p1, p2), midpoint(p2, p3), midpoint(p3, p1)]
    else:
        # Calculate midpoints of the sides
        mid1 = midpoint(p1, p2)
        mid2 = midpoint(p2, p3)
        mid3 = midpoint(p3, p1)

        # Recursive calls for the three sub-triangles
        coordinates = []
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, p1, mid1, mid3))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid1, p2, mid2))
        coordinates.extend(sierpinski_triangle_coordinates(depth - 1, mid3, mid2, p3))
        coordinates.extend([mid1, mid2, mid3])  # 수정: 현재 단계의 중점 좌표 추가
        return coordinates

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0, 0], [1, 0], [0.5, np.sqrt(3)/2]])

# 원하는 단계까지의 좌표 얻기
depth = 3
coordinates = sierpinski_triangle_coordinates(depth, triangle_points[0], triangle_points[1], triangle_points[2])

# 좌표 출력
for i, coord in enumerate(coordinates):
    print(f"Point {i + 1} coordinates: {coord}")
# Out:
# Point 1 coordinates: (0.0625, 0.0)
# Point 2 coordinates: (0.09375, 0.05412658773652741)
# Point 3 coordinates: (0.03125, 0.05412658773652741)
# Point 4 coordinates: (0.1875, 0.0)
# Point 5 coordinates: (0.21875, 0.05412658773652741)
# Point 6 coordinates: (0.15625, 0.05412658773652741)
# Point 7 coordinates: (0.125, 0.10825317547305482)
# Point 8 coordinates: (0.15625, 0.16237976320958225)
# Point 9 coordinates: (0.09375, 0.16237976320958225)
# Point 10 coordinates: (0.125, 0.0)
# Point 11 coordinates: (0.1875, 0.10825317547305482)
# Point 12 coordinates: (0.0625, 0.10825317547305482)
# Point 13 coordinates: (0.3125, 0.0)
# Point 14 coordinates: (0.34375, 0.05412658773652741)
# Point 15 coordinates: (0.28125, 0.05412658773652741)
# Point 16 coordinates: (0.4375, 0.0)
# Point 17 coordinates: (0.46875, 0.05412658773652741)
# Point 18 coordinates: (0.40625, 0.05412658773652741)
# Point 19 coordinates: (0.375, 0.10825317547305482)
# Point 20 coordinates: (0.40625, 0.16237976320958225)
# ...

# %%
import numpy as np

def midpoint_displacement(p1, p2, displacement):
    mid_x = (p1[0] + p2[0]) / 2
    mid_y = (p1[1] + p2[1]) / 2

    # Add a random displacement
    mid_x += np.random.uniform(-displacement, displacement)
    mid_y += np.random.uniform(-displacement, displacement)

    return mid_x, mid_y

def generate_midpoint_displacement(depth, p1, p2, p3, displacement):
    if depth == 0:
        return [p1, p2, p3]
    else:
        mid1 = midpoint_displacement(p1, p2, displacement)
        mid2 = midpoint_displacement(p2, p3, displacement)
        mid3 = midpoint_displacement(p3, p1, displacement)

        coordinates = []
        coordinates.extend(generate_midpoint_displacement(depth - 1, p1, mid1, mid3, displacement))
        coordinates.extend(generate_midpoint_displacement(depth - 1, mid1, p2, mid2, displacement))
        coordinates.extend(generate_midpoint_displacement(depth - 1, mid3, mid2, p3, displacement))
        return coordinates

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0, 0], [1, 0], [0.5, np.sqrt(3)/2]])

# Midpoint Displacement 알고리즘을 사용하여 좌표 얻기
depth = 5
displacement = 0.1
coordinates = generate_midpoint_displacement(depth, triangle_points[0], triangle_points[1], triangle_points[2], displacement)
for i, coord in enumerate(coordinates):
    print(f"Point {i + 1} coordinates: {coord}")
# Out:
# Point 1 coordinates: [0. 0.]
# Point 2 coordinates: (0.03508291244512063, 0.046041626853323435)
# Point 3 coordinates: (0.06839492414526957, 0.03156120241467894)
# Point 4 coordinates: (0.03508291244512063, 0.046041626853323435)
# Point 5 coordinates: (0.044938258968238415, 0.060648977131954926)
# Point 6 coordinates: (0.009573597718955912, -0.014112596789489236)
# Point 7 coordinates: (0.06839492414526957, 0.03156120241467894)
# Point 8 coordinates: (0.009573597718955912, -0.014112596789489236)
# Point 9 coordinates: (-0.0006162670407701687, 0.022409030545225833)
# Point 10 coordinates: (0.044938258968238415, 0.060648977131954926)
# Point 11 coordinates: (0.13119335889174483, -0.054508935496477416)
# Point 12 coordinates: (0.10800048639715573, 0.020507864123715684)
# Point 13 coordinates: (0.13119335889174483, -0.054508935496477416)
# Point 14 coordinates: (0.2156984179538136, -0.04337509331384373)
# Point 15 coordinates: (0.24848439394381486, -0.02003868205062742)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def sierpinski_triangle(p1, p2, p3, depth):
    if depth == 0:
        return [p1, p2, p3]
    else:
        mid1 = ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)
        mid2 = ((p2[0] + p3[0]) / 2, (p2[1] + p3[1]) / 2)
        mid3 = ((p3[0] + p1[0]) / 2, (p3[1] + p1[1]) / 2)

        vertices = [
            sierpinski_triangle(p1, mid1, mid3, depth - 1),
            sierpinski_triangle(mid1, p2, mid2, depth - 1),
            sierpinski_triangle(mid3, mid2, p3, depth - 1)
        ]

        return [item for sublist in vertices for item in sublist]

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski_triangle(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
# Point 1 coordinates: [0.0625 0.    ]
# Point 2 coordinates: (0.064453125, 0.0033829117335329633)
# Point 3 coordinates: (0.060546875, 0.0033829117335329633)
# Point 4 coordinates: (0.064453125, 0.0033829117335329633)
# Point 5 coordinates: (0.06640625, 0.0067658234670659265)
# Point 6 coordinates: (0.0625, 0.0067658234670659265)
# Point 7 coordinates: (0.060546875, 0.0033829117335329633)
# Point 8 coordinates: (0.0625, 0.0067658234670659265)
# Point 9 coordinates: (0.05859375, 0.0067658234670659265)
# Point 10 coordinates: (0.06640625, 0.0067658234670659265)
# Point 11 coordinates: (0.068359375, 0.01014873520059889)
# Point 12 coordinates: (0.064453125, 0.01014873520059889)
# Point 13 coordinates: (0.068359375, 0.01014873520059889)
# Point 14 coordinates: (0.0703125, 0.013531646934131853)
# Point 15 coordinates: (0.06640625, 0.013531646934131853)
# Point 16 coordinates: (0.064453125, 0.01014873520059889)
# Point 17 coordinates: (0.06640625, 0.013531646934131853)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(p1, p2, p3, depth):
    if depth == 0:
        return [p1, p2, p3]
    
    mid1 = midpoint(p1, p2)
    mid2 = midpoint(p2, p3)
    mid3 = midpoint(p3, p1)

    points = sierpinski(p1, mid1, mid3, depth - 1) + \
             sierpinski(mid1, p2, mid2, depth - 1) + \
             sierpinski(mid3, mid2, p3, depth - 1)
    
    return points

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
# Point 1 coordinates: [0.0625 0.    ]
# Point 2 coordinates: (0.064453125, 0.0033829117335329633)
# Point 3 coordinates: (0.060546875, 0.0033829117335329633)
# Point 4 coordinates: (0.064453125, 0.0033829117335329633)
# Point 5 coordinates: (0.06640625, 0.0067658234670659265)
# Point 6 coordinates: (0.0625, 0.0067658234670659265)
# Point 7 coordinates: (0.060546875, 0.0033829117335329633)
# Point 8 coordinates: (0.0625, 0.0067658234670659265)
# Point 9 coordinates: (0.05859375, 0.0067658234670659265)
# Point 10 coordinates: (0.06640625, 0.0067658234670659265)
# Point 11 coordinates: (0.068359375, 0.01014873520059889)
# Point 12 coordinates: (0.064453125, 0.01014873520059889)
# Point 13 coordinates: (0.068359375, 0.01014873520059889)
# Point 14 coordinates: (0.0703125, 0.013531646934131853)
# Point 15 coordinates: (0.06640625, 0.013531646934131853)
# Point 16 coordinates: (0.064453125, 0.01014873520059889)
# Point 17 coordinates: (0.06640625, 0.013531646934131853)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(p1, p2, p3, depth):
    if depth == 0:
        return [p1, p2, p3]
    
    mid1 = midpoint(p1, p2)
    mid2 = midpoint(p2, p3)
    mid3 = midpoint(p3, p1)

    points = sierpinski(p1, mid1, mid3, depth - 1) + \
             sierpinski(mid1, p2, mid2, depth - 1) + \
             sierpinski(mid3, mid2, p3, depth - 1)
    
    return points

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
# Point 1 coordinates: [0.0625 0.    ]
# Point 2 coordinates: (0.064453125, 0.0033829117335329633)
# Point 3 coordinates: (0.060546875, 0.0033829117335329633)
# Point 4 coordinates: (0.064453125, 0.0033829117335329633)
# Point 5 coordinates: (0.06640625, 0.0067658234670659265)
# Point 6 coordinates: (0.0625, 0.0067658234670659265)
# Point 7 coordinates: (0.060546875, 0.0033829117335329633)
# Point 8 coordinates: (0.0625, 0.0067658234670659265)
# Point 9 coordinates: (0.05859375, 0.0067658234670659265)
# Point 10 coordinates: (0.06640625, 0.0067658234670659265)
# Point 11 coordinates: (0.068359375, 0.01014873520059889)
# Point 12 coordinates: (0.064453125, 0.01014873520059889)
# Point 13 coordinates: (0.068359375, 0.01014873520059889)
# Point 14 coordinates: (0.0703125, 0.013531646934131853)
# Point 15 coordinates: (0.06640625, 0.013531646934131853)
# Point 16 coordinates: (0.064453125, 0.01014873520059889)
# Point 17 coordinates: (0.06640625, 0.013531646934131853)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(p1, p2, p3, depth, points=None):
    if points is None:
        points = [p1, p2, p3]

    if depth == 0:
        return points
    
    mid1 = midpoint(p1, p2)
    mid2 = midpoint(p2, p3)
    mid3 = midpoint(p3, p1)

    sierpinski(p1, mid1, mid3, depth - 1, points)
    sierpinski(mid1, p2, mid2, depth - 1, points)
    sierpinski(mid3, mid2, p3, depth - 1, points)
    
    return points

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
# Point 1 coordinates: [0.0625 0.    ]
# Point 2 coordinates: [0.09375    0.05412659]
# Point 3 coordinates: [0.03125    0.05412659]

# %%
import numpy as np
import matplotlib.pyplot as plt

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(p1, p2, p3, depth):
    if depth == 0:
        return [p1, p2, p3]
    
    mid1 = midpoint(p1, p2)
    mid2 = midpoint(p2, p3)
    mid3 = midpoint(p3, p1)

    points = sierpinski(p1, mid1, mid3, depth - 1) + \
             sierpinski(mid1, p2, mid2, depth - 1) + \
             sierpinski(mid3, mid2, p3, depth - 1) + \

    return points

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
#   Cell In[12], line 18
#
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(p1, p2, p3, depth, points=None):
    if points is None:
        points = [p1, p2, p3]

    if depth > 0:
        mid1 = midpoint(p1, p2)
        mid2 = midpoint(p2, p3)
        mid3 = midpoint(p3, p1)

        sierpinski(p1, mid1, mid3, depth - 1, points)
        sierpinski(mid1, p2, mid2, depth - 1, points)
        sierpinski(mid3, mid2, p3, depth - 1, points)
    return points

# 초기 삼각형의 꼭짓점 좌표
triangle_points = np.array([[0.0625, 0.0], [0.09375, 0.05412658773652741], [0.03125, 0.05412658773652741]])

# Sierpinski 삼각형을 생성하는 함수 호출
depth = 4
resulting_points = sierpinski(triangle_points[0], triangle_points[1], triangle_points[2], depth)

# 결과 좌표 출력
for i, coord in enumerate(resulting_points):
    print(f"Point {i + 1} coordinates: {coord}")

# 시각화
resulting_points = np.array(resulting_points)
plt.scatter(resulting_points[:, 0], resulting_points[:, 1], s=10, c='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sierpinski Triangle')
plt.show()
# Out:
# Point 1 coordinates: [0.0625 0.    ]
# Point 2 coordinates: [0.09375    0.05412659]
# Point 3 coordinates: [0.03125    0.05412659]

# %%
import turtle

def draw_triangle(vertices):
    turtle.penup()
    turtle.goto(vertices[0][0], vertices[0][1])
    turtle.pendown()
    turtle.goto(vertices[1][0], vertices[1][1])
    turtle.goto(vertices[2][0], vertices[2][1])
    turtle.goto(vertices[0][0], vertices[0][1])

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski_triangle(vertices, depth):
    draw_triangle(vertices)
    if depth > 0:
        sierpinski_triangle([vertices[0],
                             midpoint(vertices[0], vertices[1]),
                             midpoint(vertices[0], vertices[2])],
                            depth - 1)
        sierpinski_triangle([vertices[1],
                             midpoint(vertices[0], vertices[1]),
                             midpoint(vertices[1], vertices[2])],
                            depth - 1)
        sierpinski_triangle([vertices[2],
                             midpoint(vertices[2], vertices[1]),
                             midpoint(vertices[0], vertices[2])],
                            depth - 1)

def main():
    turtle.speed(2)
    turtle.hideturtle()
    turtle.title("Sierpinski Triangle")

    # 초기 삼각형의 꼭지점 좌표
    vertices = [(-200, -100), (0, 200), (200, -100)]

    # 재귀 호출을 통해 삼각형을 그림
    sierpinski_triangle(vertices, 4)

    turtle.done()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 44
#      41     turtle.done()
#      43 if __name__ == "__main__":
# ---> 44     main()
#
# Cell In[14], line 39, in main()
#      36 vertices = [(-200, -100), (0, 200), (200, -100)]
#      38 # 재귀 호출을 통해 삼각형을 그림
# ---> 39 sierpinski_triangle(vertices, 4)
#      41 turtle.done()
#
# Cell In[14], line 17, in sierpinski_triangle(vertices, depth)
#      15 draw_triangle(vertices)
#      16 if depth > 0:
# ---> 17     sierpinski_triangle([vertices[0],
#      18                          midpoint(vertices[0], vertices[1]),
#      19                          midpoint(vertices[0], vertices[2])],
#      20                         depth - 1)
#      21     sierpinski_triangle([vertices[1],
#      22                          midpoint(vertices[0], vertices[1]),
# ...

# %%
import turtle

def draw_triangle(vertices):
    turtle.penup()
    turtle.goto(vertices[0][0], vertices[0][1])
    turtle.pendown()
    turtle.goto(vertices[1][0], vertices[1][1])
    turtle.goto(vertices[2][0], vertices[2][1])
    turtle.goto(vertices[0][0], vertices[0][1])

def midpoint(p1, p2):
    return ((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski_triangle(vertices, depth):
    draw_triangle(vertices)
    if depth > 0:
        sierpinski_triangle([vertices[0],
                             midpoint(vertices[0], vertices[1]),
                             midpoint(vertices[0], vertices[2])],
                            depth - 1)
        sierpinski_triangle([vertices[1],
                             midpoint(vertices[0], vertices[1]),
                             midpoint(vertices[1], vertices[2])],
                            depth - 1)
        sierpinski_triangle([vertices[2],
                             midpoint(vertices[2], vertices[1]),
                             midpoint(vertices[0], vertices[2])],
                            depth - 1)

def main():
    turtle.speed(2)
    turtle.hideturtle()
    turtle.title("Sierpinski Triangle")

    # 초기 삼각형의 꼭지점 좌표
    vertices = [(-200, -100), (0, 200), (200, -100)]

    # 재귀 호출을 통해 삼각형을 그림
    sierpinski_triangle(vertices, 4)

    turtle.mainloop()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 44
#      41     turtle.mainloop()
#      43 if __name__ == "__main__":
# ---> 44     main()
#
# Cell In[15], line 39, in main()
#      36 vertices = [(-200, -100), (0, 200), (200, -100)]
#      38 # 재귀 호출을 통해 삼각형을 그림
# ---> 39 sierpinski_triangle(vertices, 4)
#      41 turtle.mainloop()
#
# Cell In[15], line 17, in sierpinski_triangle(vertices, depth)
#      15 draw_triangle(vertices)
#      16 if depth > 0:
# ---> 17     sierpinski_triangle([vertices[0],
#      18                          midpoint(vertices[0], vertices[1]),
#      19                          midpoint(vertices[0], vertices[2])],
#      20                         depth - 1)
#      21     sierpinski_triangle([vertices[1],
#      22                          midpoint(vertices[0], vertices[1]),
# ...

# %%
import turtle

# 이하 함수 정의 및 코드 생략

def main():
    turtle.speed(2)
    turtle.hideturtle()
    turtle.title("Sierpinski Triangle")

    # 초기 삼각형의 꼭지점 좌표
    vertices = [(-200, -100), (0, 200), (200, -100)]

    # 재귀 호출을 통해 삼각형을 그림
    sierpinski_triangle(vertices, 4)

    turtle.done()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 19
#      16     turtle.done()
#      18 if __name__ == "__main__":
# ---> 19     main()
#
# Cell In[16], line 14, in main()
#      11 vertices = [(-200, -100), (0, 200), (200, -100)]
#      13 # 재귀 호출을 통해 삼각형을 그림
# ---> 14 sierpinski_triangle(vertices, 4)
#      16 turtle.done()
#
# Cell In[15], line 15, in sierpinski_triangle(vertices, depth)
#      14 def sierpinski_triangle(vertices, depth):
# ---> 15     draw_triangle(vertices)
#      16     if depth > 0:
#      17         sierpinski_triangle([vertices[0],
#      18                              midpoint(vertices[0], vertices[1]),
#      19                              midpoint(vertices[0], vertices[2])],
#      20                             depth - 1)
#
# Cell In[15], line 9, in draw_triangle(vertices)
#       7 turtle.goto(vertices[1][0], vertices[1][1])
# ...

# %%
def sierpinski_coordinates(vertices, depth):
    if depth == 0:
        return vertices
    else:
        midpoints = [
            ((vertices[0][0] + vertices[1][0]) / 2, (vertices[0][1] + vertices[1][1]) / 2),
            ((vertices[1][0] + vertices[2][0]) / 2, (vertices[1][1] + vertices[2][1]) / 2),
            ((vertices[2][0] + vertices[0][0]) / 2, (vertices[2][1] + vertices[0][1]) / 2)
        ]

        # 재귀적으로 작은 삼각형의 좌표를 얻습니다.
        lower_triangles = [
            sierpinski_coordinates([vertices[0], midpoints[0], midpoints[2]], depth - 1),
            sierpinski_coordinates([midpoints[0], vertices[1], midpoints[1]], depth - 1),
            sierpinski_coordinates([midpoints[2], midpoints[1], vertices[2]], depth - 1)
        ]

        # 중간 지점을 포함한 좌표를 반환합니다.
        return [midpoints[0]] + lower_triangles[0] + \
               [midpoints[1]] + lower_triangles[1] + \
               [midpoints[2]] + lower_triangles[2]

# 초기 삼각형의 세 꼭지점 좌표
initial_triangle = [(0, 0), (1, 0), (0.5, 0.866)]

# 좌표를 얻고 출력합니다.
coordinates = sierpinski_coordinates(initial_triangle, depth=3)
for point in coordinates:
    print(point)
# Out:
# (0.5, 0.0)
# (0.25, 0.0)
# (0.125, 0.0)
# (0, 0)
# (0.125, 0.0)
# (0.0625, 0.10825)
# (0.1875, 0.10825)
# (0.125, 0.0)
# (0.25, 0.0)
# (0.1875, 0.10825)
# (0.0625, 0.10825)
# (0.0625, 0.10825)
# (0.1875, 0.10825)
# (0.125, 0.2165)
# (0.375, 0.2165)
# (0.375, 0.0)
# (0.25, 0.0)
# (0.375, 0.0)
# (0.3125, 0.10825)
# (0.4375, 0.10825)
# (0.375, 0.0)
# (0.5, 0.0)
# (0.4375, 0.10825)
# (0.3125, 0.10825)
# (0.3125, 0.10825)
# (0.4375, 0.10825)
# (0.375, 0.2165)
# (0.125, 0.2165)
# (0.25, 0.2165)
# (0.125, 0.2165)
# (0.25, 0.2165)
# (0.1875, 0.32475)
# (0.3125, 0.32475)
# (0.25, 0.2165)
# (0.375, 0.2165)
# (0.3125, 0.32475)
# (0.1875, 0.32475)
# (0.1875, 0.32475)
# (0.3125, 0.32475)
# (0.25, 0.433)
# (0.75, 0.433)
# (0.75, 0.0)
# (0.625, 0.0)
# (0.5, 0.0)
# (0.625, 0.0)
# (0.5625, 0.10825)
# (0.6875, 0.10825)
# (0.625, 0.0)
# (0.75, 0.0)
# (0.6875, 0.10825)
# (0.5625, 0.10825)
# (0.5625, 0.10825)
# (0.6875, 0.10825)
# (0.625, 0.2165)
# (0.875, 0.2165)
# (0.875, 0.0)
# (0.75, 0.0)
# ...

# %%
def generate_slerpinski_triangle(steps):
    triangles = [(0,0),(1,0),(0.5,0.866)]
    
    for step in range(steps):
        new_triangles = []
        for triangle in triangles:
            p1,p2,p3 = triangle
            midpoints = [(p1[0]+p2[0]/2,p1[1]+p2[1]/2),
                         (p2[0]+p3[0]/2,p2[1]+p3[1]/2),
                         (p1[0]+p3[0]/2,p1[1]+p3[1]/2)]
            new_triangles.extend(
            [p1,midpoints[0],midpoints[2]],
            [midpoints[0],p2,midpoints[1]],
            [midpoints[2],midpoints[1],p3])
            triangles = new_triangles
            
            print(f"Step{step+1}좌표:")
            for triangle in triangles:
                print(triangle)
user_steps = int(input("몇 단계의 시에르핀스키 삼각형 출력?: "))
generate_sierpinski_triangle(user_steps)
# Out:
# 몇 단계의 시에르핀스키 삼각형 출력?: 5
# Step 1 좌표:
# [(0, 0), (0.5, 0.0), (0.25, 0.433)]
# [(0.5, 0.0), (1, 0), (0.75, 0.433)]
# [(0.25, 0.433), (0.75, 0.433), (0.5, 0.866)]
# Step 2 좌표:
# [(0, 0), (0.25, 0.0), (0.125, 0.2165)]
# [(0.25, 0.0), (0.5, 0.0), (0.375, 0.2165)]
# [(0.125, 0.2165), (0.375, 0.2165), (0.25, 0.433)]
# [(0.5, 0.0), (0.75, 0.0), (0.625, 0.2165)]
# [(0.75, 0.0), (1, 0), (0.875, 0.2165)]
# [(0.625, 0.2165), (0.875, 0.2165), (0.75, 0.433)]
# [(0.25, 0.433), (0.5, 0.433), (0.375, 0.6495)]
# [(0.5, 0.433), (0.75, 0.433), (0.625, 0.6495)]
# [(0.375, 0.6495), (0.625, 0.6495), (0.5, 0.866)]
# Step 3 좌표:
# [(0, 0), (0.125, 0.0), (0.0625, 0.10825)]
# [(0.125, 0.0), (0.25, 0.0), (0.1875, 0.10825)]
# [(0.0625, 0.10825), (0.1875, 0.10825), (0.125, 0.2165)]
# [(0.25, 0.0), (0.375, 0.0), (0.3125, 0.10825)]
# [(0.375, 0.0), (0.5, 0.0), (0.4375, 0.10825)]
# [(0.3125, 0.10825), (0.4375, 0.10825), (0.375, 0.2165)]
# [(0.125, 0.2165), (0.25, 0.2165), (0.1875, 0.32475)]
# ...

# %%
def generate_sierpinski_triangle(steps):
    triangles = [[(0, 0), (1, 0), (0.5, 0.866)]]

    for step in range(steps):
        new_triangles = []
        for triangle in triangles:
            p1, p2, p3 = triangle
            midpoints = [((p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2),
                         ((p2[0] + p3[0]) / 2, (p2[1] + p3[1]) / 2),
                         ((p1[0] + p3[0]) / 2, (p1[1] + p3[1]) / 2)]
            new_triangles.extend([
                [p1, midpoints[0], midpoints[2]],
                [midpoints[0], p2, midpoints[1]],
                [midpoints[2], midpoints[1], p3]
            ])
        triangles = new_triangles

        print(f"Step {step + 1} 좌표:")
        for triangle in triangles:
            print(triangle)

user_steps = int(input("몇 단계의 시에르핀스키 삼각형을 출력하시겠습니까? "))
generate_sierpinski_triangle(user_steps)
# Out:
# 몇 단계의 시에르핀스키 삼각형을 출력하시겠습니까? 5
# Step 1 좌표:
# [(0, 0), (0.5, 0.0), (0.25, 0.433)]
# [(0.5, 0.0), (1, 0), (0.75, 0.433)]
# [(0.25, 0.433), (0.75, 0.433), (0.5, 0.866)]
# Step 2 좌표:
# [(0, 0), (0.25, 0.0), (0.125, 0.2165)]
# [(0.25, 0.0), (0.5, 0.0), (0.375, 0.2165)]
# [(0.125, 0.2165), (0.375, 0.2165), (0.25, 0.433)]
# [(0.5, 0.0), (0.75, 0.0), (0.625, 0.2165)]
# [(0.75, 0.0), (1, 0), (0.875, 0.2165)]
# [(0.625, 0.2165), (0.875, 0.2165), (0.75, 0.433)]
# [(0.25, 0.433), (0.5, 0.433), (0.375, 0.6495)]
# [(0.5, 0.433), (0.75, 0.433), (0.625, 0.6495)]
# [(0.375, 0.6495), (0.625, 0.6495), (0.5, 0.866)]
# Step 3 좌표:
# [(0, 0), (0.125, 0.0), (0.0625, 0.10825)]
# [(0.125, 0.0), (0.25, 0.0), (0.1875, 0.10825)]
# [(0.0625, 0.10825), (0.1875, 0.10825), (0.125, 0.2165)]
# [(0.25, 0.0), (0.375, 0.0), (0.3125, 0.10825)]
# [(0.375, 0.0), (0.5, 0.0), (0.4375, 0.10825)]
# [(0.3125, 0.10825), (0.4375, 0.10825), (0.375, 0.2165)]
# [(0.125, 0.2165), (0.25, 0.2165), (0.1875, 0.32475)]
# ...
